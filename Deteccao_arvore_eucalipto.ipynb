# %% [markdown]
# ### PASSO 01 - Execute comando abaixo para clonar o YOLO

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 9884, done.
# remote: Counting objects: 100% (83/83), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 9884 (delta 43), reused 30 (delta 11), pack-reused 9801
# Receiving objects: 100% (9884/9884), 10.36 MiB | 11.51 MiB/s, done.
# Resolving deltas: 100% (6830/6830), done.

# %% [markdown]
# ####-Integre o Google Drive com o Google Colab usando a opção **MountDrive**
# ![enter image description here](https://miro.medium.com/max/606/1*SkaEHO70zA1Of0-8GQCjvQ.png)

# %% [markdown]
# ### PASSO 02 - Execute o comando abaixo para entrar no diretório yolov5

# %%
# %cd yolov5
# Out:
# [Errno 2] No such file or directory: 'yolov5'
# /content

# %% [markdown]
# ### PASSO 03 - Execute o comando abaixo para instalar todas as dependências que o Yolo precisa

# %%
# %pip install -r requirements.txt

# %% [markdown]
# # ATENÇÃO
# ## Caso queira somente detectar objetos pular para o PASSO 05.
#
#
# ---
#
#
# ### O arquivo **train.py** é responsável pelo treinamento, a execução do comando abaixo dá inicio ao treinamento da rede.

# %% [markdown]
# ### PASSO 04 - Execute o comando abaixo Iniciar o treinamento da Rede

# %%
# !python train.py --img 640 --batch 32 --epochs 225 --data /content/drive/MyDrive/yolo/coco128.yaml --weights yolov5s.pt

# %% [markdown]
# ### PASSO 05 -
# #####-Se quiser somente detectar sem passar pela etapa de treinamento execute o comando abaixo.
#     !python detect.py  --weights /content/drive/MyDrive/yolo/best.pt --conf 0.5 --source /content/drive/MyDrive/image_test/teste/RECORTE_01.jpg
#
# ####-Se quiser somente detectar passando pela etapa de treinamento execute o comando abaixo.
#
#     !python detect.py  --weights /runs/exp/wights/best.pt --conf 0.5 --source /content/drive/MyDrive/image_test/teste/RECORTE_01.jpg

# %%
# !python detect.py  --weights /content/drive/MyDrive/yolo/best.pt --conf 0.5 --source /content/drive/MyDrive/imagens_test/RECORTE_01.jpg
